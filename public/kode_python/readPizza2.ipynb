# %%
#membaca dataset heart_failure_clinical_records_dataset
import pandas as pd
Datanya_50= pd.read_csv('pizza_sales.csv')
Datanya_50
# Out:
#        pizza_id  order_id  pizza_name_id  quantity  order_date order_time  \
# 0           1.0       1.0     hawaiian_m       1.0    1/1/2015   11:38:36
# 1           2.0       2.0  classic_dlx_m       1.0    1/1/2015   11:57:40
# 2           3.0       2.0  five_cheese_l       1.0    1/1/2015   11:57:40
# 3           4.0       2.0    ital_supr_l       1.0    1/1/2015   11:57:40
# 4           5.0       2.0     mexicana_m       1.0    1/1/2015   11:57:40
# ...         ...       ...            ...       ...         ...        ...
# 48615   48616.0   21348.0  ckn_alfredo_m       1.0  31-12-2015   21:23:10
# 48616   48617.0   21348.0  four_cheese_l       1.0  31-12-2015   21:23:10
# 48617   48618.0   21348.0   napolitana_s       1.0  31-12-2015   21:23:10
# 48618   48619.0   21349.0     mexicana_l       1.0  31-12-2015   22:09:54
# 48619   48620.0   21350.0      bbq_ckn_s       1.0  31-12-2015   23:02:05
#
#        unit_price  total_price pizza_size pizza_category  \
# 0           13.25        13.25          M        Classic
# 1           16.00        16.00          M        Classic
# 2           18.50        18.50          L         Veggie
# 3           20.75        20.75          L        Supreme
# 4           16.00        16.00          M         Veggie
# ...           ...          ...        ...            ...
# 48615       16.75        16.75          M        Chicken
# 48616       17.95        17.95          L         Veggie
# 48617       12.00        12.00          S        Classic
# 48618       20.25        20.25          L         Veggie
# 48619       12.75        12.75          S        Chicken
#
#                                        pizza_ingredients  \
# 0               Sliced Ham, Pineapple, Mozzarella Cheese
# 1      Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2      Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3      Calabrese Salami, Capocollo, Tomatoes, Red Oni...
# 4      Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
# ...                                                  ...
# 48615  Chicken, Red Onions, Red Peppers, Mushrooms, A...
# 48616  Ricotta Cheese, Gorgonzola Piccante Cheese, Mo...
# 48617  Tomatoes, Anchovies, Green Olives, Red Onions,...
# 48618  Tomatoes, Red Peppers, Jalapeno Peppers, Red O...
# 48619  Barbecued Chicken, Red Peppers, Green Peppers,...
#
#                        pizza_name
# 0              The Hawaiian Pizza
# 1        The Classic Deluxe Pizza
# 2           The Five Cheese Pizza
# 3       The Italian Supreme Pizza
# 4              The Mexicana Pizza
# ...                           ...
# 48615   The Chicken Alfredo Pizza
# 48616       The Four Cheese Pizza
# 48617        The Napolitana Pizza
# 48618          The Mexicana Pizza
# 48619  The Barbecue Chicken Pizza
#
# [48620 rows x 12 columns]

# %%
Datanya_50['order_date'] = Datanya_50['order_date'].str.replace('/', '-')

# %%
Datanya_50['order_date'] = pd.to_datetime(Datanya_50['order_date'], format='%d-%m-%Y')

# %%
PilihKolom = Datanya_50[['order_id', 'order_date','pizza_size', 'pizza_name']]
PilihKolom
# Out:
#        order_id order_date pizza_size                  pizza_name
# 0           1.0 2015-01-01          M          The Hawaiian Pizza
# 1           2.0 2015-01-01          M    The Classic Deluxe Pizza
# 2           2.0 2015-01-01          L       The Five Cheese Pizza
# 3           2.0 2015-01-01          L   The Italian Supreme Pizza
# 4           2.0 2015-01-01          M          The Mexicana Pizza
# ...         ...        ...        ...                         ...
# 48615   21348.0 2015-12-31          M   The Chicken Alfredo Pizza
# 48616   21348.0 2015-12-31          L       The Four Cheese Pizza
# 48617   21348.0 2015-12-31          S        The Napolitana Pizza
# 48618   21349.0 2015-12-31          L          The Mexicana Pizza
# 48619   21350.0 2015-12-31          S  The Barbecue Chicken Pizza
#
# [48620 rows x 4 columns]

# %%
PilihKolom[14200:16300]
# Out:
#        order_id order_date pizza_size  \
# 14200    6211.0 2015-04-15          S
# 14201    6212.0 2015-04-15          L
# 14202    6213.0 2015-04-15          L
# 14203    6213.0 2015-04-15          L
# 14204    6214.0 2015-04-15          S
# ...         ...        ...        ...
# 16295    7167.0 2015-04-30          S
# 16296    7167.0 2015-04-30          S
# 16297    7168.0 2015-04-30          L
# 16298    7169.0 2015-04-30          S
# 16299    7169.0 2015-04-30          L
#
#                                        pizza_name
# 14200  The Pepperoni, Mushroom, and Peppers Pizza
# 14201                  The Barbecue Chicken Pizza
# 14202                 The Italian Capocollo Pizza
# 14203           The Vegetables + Vegetables Pizza
# 14204                    The Classic Deluxe Pizza
# ...                                           ...
# 16295                          The Hawaiian Pizza
# 16296                          The Sicilian Pizza
# 16297                       The Five Cheese Pizza
# 16298                      The Green Garden Pizza
# 16299                 The Southwest Chicken Pizza
#
# [2100 rows x 4 columns]

# %%
# Tambahkan kolom 'week_number' berdasarkan minggu dari tanggal
PilihKolom['week_number'] = PilihKolom['order_date'].dt.isocalendar().week
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_20408\824588110.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PilihKolom['order_date'] = pd.to_datetime(PilihKolom['order_date'])
# C:\Users\User\AppData\Local\Temp\ipykernel_20408\824588110.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PilihKolom['week_number'] = PilihKolom['order_date'].dt.isocalendar().week

# %%
# Kelompokkan berdasarkan minggu
grouped = PilihKolom.groupby('week_number')

# Pisahkan DataFrame untuk setiap minggu
weekly_dataframes = {week: group for week, group in grouped}

# Simpan setiap minggu ke file CSV (opsional) dan tampilkan hasil
for week, df in weekly_dataframes.items():
    print(f"Data untuk Minggu ke-{week}:")
    print(df)
    print("\n")

    # Opsional: Simpan ke file CSV
    # df.to_csv(f"week_{week}.csv", index=False)
# Out:
# Data untuk Minggu ke-1:
#      order_details_id  order_id order_date pizza_size  \
# 0                   1         1 2015-01-01          M
# 1                   2         2 2015-01-01          M
# 2                   3         2 2015-01-01          L
# 3                   4         2 2015-01-01          L
# 4                   5         2 2015-01-01          M
# ..                ...       ...        ...        ...
# 576               577       252 2015-01-04          M
# 577               578       253 2015-01-04          S
# 578               579       254 2015-01-04          L
# 579               580       254 2015-01-04          S
# 580               581       254 2015-01-04          L
#
#                            pizza_name  week_number
# 0                  The Hawaiian Pizza            1
# 1            The Classic Deluxe Pizza            1
# 2               The Five Cheese Pizza            1
# 3           The Italian Supreme Pizza            1
# 4                  The Mexicana Pizza            1
# ..                                ...          ...
# 576  The Prosciutto and Arugula Pizza            1
# 577              The Brie Carre Pizza            1
# 578        The Barbecue Chicken Pizza            1
# 579              The Brie Carre Pizza            1
# 580             The Five Cheese Pizza            1
#
# [581 rows x 6 columns]
#
#
# Data untuk Minggu ke-2:
#       order_details_id  order_id order_date pizza_size  \
# 581                582       255 2015-01-05          L
# 582                583       255 2015-01-05          M
# 583                584       255 2015-01-05          L
# 584                585       255 2015-01-05          M
# 585                586       256 2015-01-05          L
# ...                ...       ...        ...        ...
# 1527              1528       679 2015-01-11          L
# 1528              1529       679 2015-01-11          L
# 1529              1530       680 2015-01-11          S
# 1530              1531       680 2015-01-11          M
# 1531              1532       681 2015-01-11          L
#
#                                       pizza_name  week_number
# 581                        The Five Cheese Pizza            2
# 582                       The Green Garden Pizza            2
# 583                           The Hawaiian Pizza            2
# 584                   The Spinach and Feta Pizza            2
# 585   The Pepperoni, Mushroom, and Peppers Pizza            2
# ...                                          ...          ...
# 1527                   The Italian Supreme Pizza            2
# 1528                     The Mediterranean Pizza            2
# 1529                     The Chicken Pesto Pizza            2
# 1530                          The Sicilian Pizza            2
# 1531                     The Pepper Salami Pizza            2
#
# [951 rows x 6 columns]
#
#
# Data untuk Minggu ke-3:
#       order_details_id  order_id order_date pizza_size  \
# 1532              1533       682 2015-01-12          L
# 1533              1534       683 2015-01-12          L
# 1534              1535       683 2015-01-12          S
# 1535              1536       683 2015-01-12          M
# 1536              1537       684 2015-01-12          L
# ...                ...       ...        ...        ...
# 2425              2426      1080 2015-01-18          M
# 2426              2427      1080 2015-01-18          L
# 2427              2428      1080 2015-01-18          S
# 2428              2429      1080 2015-01-18          M
# 2429              2430      1081 2015-01-18          L
#
#                         pizza_name  week_number
# 1532     The Italian Supreme Pizza            3
# 1533       The Chicken Pesto Pizza            3
# 1534  The Italian Vegetables Pizza            3
# 1535       The Pepper Salami Pizza            3
# 1536         The Four Cheese Pizza            3
# ...                            ...          ...
# 2425  The Italian Vegetables Pizza            3
# 2426            The Sicilian Pizza            3
# 2427         The Soppressata Pizza            3
# 2428       The Spicy Italian Pizza            3
# 2429         The Five Cheese Pizza            3
#
# [898 rows x 6 columns]
#
#
# Data untuk Minggu ke-4:
#       order_details_id  order_id order_date pizza_size  \
# 2430              2431      1082 2015-01-19          L
# 2431              2432      1082 2015-01-19          L
# 2432              2433      1083 2015-01-19          L
# 2433              2434      1084 2015-01-19          S
# 2434              2435      1085 2015-01-19          S
# ...                ...       ...        ...        ...
# 3377              3378      1494 2015-01-25          L
# 3378              3379      1495 2015-01-25          S
# 3379              3380      1495 2015-01-25          S
# 3380              3381      1495 2015-01-25          S
# 3381              3382      1496 2015-01-25          L
#
#                              pizza_name  week_number
# 2430            The Pepper Salami Pizza            4
# 2431             The Thai Chicken Pizza            4
# 2432        The Southwest Chicken Pizza            4
# 2433                 The Big Meat Pizza            4
# 2434                 The Hawaiian Pizza            4
# ...                                 ...          ...
# 3377  The Vegetables + Vegetables Pizza            4
# 3378                 The Mexicana Pizza            4
# 3379            The Spicy Italian Pizza            4
# 3380            The Spinach Pesto Pizza            4
# 3381               The Napolitana Pizza            4
#
# [952 rows x 6 columns]
#
#
# Data untuk Minggu ke-5:
#       order_details_id  order_id order_date pizza_size  \
# 3382              3383      1497 2015-01-26          S
# 3383              3384      1497 2015-01-26          L
# 3384              3385      1497 2015-01-26          M
# 3385              3386      1498 2015-01-26          L
# 3386              3387      1499 2015-01-26          L
# ...                ...       ...        ...        ...
# 4339              4340      1930 2015-02-01          M
# 4340              4341      1931 2015-02-01          S
# 4341              4342      1931 2015-02-01          M
# 4342              4343      1932 2015-02-01          L
# 4343              4344      1932 2015-02-01          M
#
#                         pizza_name  week_number
# 3382            The Big Meat Pizza            5
# 3383           The Calabrese Pizza            5
# 3384     The Italian Supreme Pizza            5
# 3385        The Thai Chicken Pizza            5
# 3386            The Hawaiian Pizza            5
# ...                            ...          ...
# 4339           The Calabrese Pizza            5
# 4340            The Big Meat Pizza            5
# 4341   The Southwest Chicken Pizza            5
# 4342  The California Chicken Pizza            5
# 4343        The Thai Chicken Pizza            5
#
# [962 rows x 6 columns]
#
#
# Data untuk Minggu ke-6:
#       order_details_id  order_id order_date pizza_size  \
# 4344              4345      1933 2015-02-02          M
# 4345              4346      1933 2015-02-02          M
# 4346              4347      1933 2015-02-02          L
# 4347              4348      1933 2015-02-02          M
# 4348              4349      1934 2015-02-02          M
# ...                ...       ...        ...        ...
# 5311              5312      2353 2015-02-08          S
# 5312              5313      2354 2015-02-08          S
# 5313              5314      2354 2015-02-08          M
# 5314              5315      2354 2015-02-08          L
# 5315              5316      2354 2015-02-08          L
#
#                              pizza_name  week_number
# 4344       The California Chicken Pizza            6
# 4345       The Italian Vegetables Pizza            6
# 4346             The Thai Chicken Pizza            6
# 4347             The Thai Chicken Pizza            6
# 4348       The California Chicken Pizza            6
# ...                                 ...          ...
# 5311             The Thai Chicken Pizza            6
# 5312                 The Mexicana Pizza            6
# 5313   The Prosciutto and Arugula Pizza            6
# 5314          The Spinach Supreme Pizza            6
# 5315  The Vegetables + Vegetables Pizza            6
#
# [972 rows x 6 columns]
#
#
# Data untuk Minggu ke-7:
#       order_details_id  order_id order_date pizza_size  \
# 5316              5317      2355 2015-02-09          M
# 5317              5318      2356 2015-02-09          S
# 5318              5319      2357 2015-02-09         XL
# 5319              5320      2358 2015-02-09          M
# 5320              5321      2358 2015-02-09          M
# ...                ...       ...        ...        ...
# 6271              6272      2775 2015-02-15          M
# 6272              6273      2776 2015-02-15          M
# 6273              6274      2776 2015-02-15         XL
# 6274              6275      2776 2015-02-15          M
# 6275              6276      2777 2015-02-15          S
#
#                              pizza_name  week_number
# 5316                 The Mexicana Pizza            7
# 5317                    The Greek Pizza            7
# 5318                    The Greek Pizza            7
# 5319       The California Chicken Pizza            7
# 5320          The Italian Supreme Pizza            7
# ...                                 ...          ...
# 6271           The Classic Deluxe Pizza            7
# 6272          The Chicken Alfredo Pizza            7
# 6273                    The Greek Pizza            7
# 6274  The Vegetables + Vegetables Pizza            7
# 6275       The Italian Vegetables Pizza            7
#
# [960 rows x 6 columns]
#
#
# Data untuk Minggu ke-8:
#       order_details_id  order_id order_date pizza_size  \
# 6276              6277      2778 2015-02-16          S
# 6277              6278      2779 2015-02-16          M
# 6278              6279      2779 2015-02-16          L
# 6279              6280      2780 2015-02-16          L
# 6280              6281      2781 2015-02-16          S
# ...                ...       ...        ...        ...
# 7185              7186      3169 2015-02-22          S
# 7186              7187      3169 2015-02-22          S
# 7187              7188      3170 2015-02-22          L
# 7188              7189      3170 2015-02-22          M
# 7189              7190      3170 2015-02-22          S
#
#                       pizza_name  week_number
# 6276      The Green Garden Pizza            8
# 6277    The Classic Deluxe Pizza            8
# 6278       The Four Cheese Pizza            8
# 6279     The Mediterranean Pizza            8
# 6280          The Big Meat Pizza            8
# ...                          ...          ...
# 7185          The Hawaiian Pizza            8
# 7186  The Spinach and Feta Pizza            8
# 7187    The Classic Deluxe Pizza            8
# 7188     The Spinach Pesto Pizza            8
# 7189      The Thai Chicken Pizza            8
#
# [914 rows x 6 columns]
#
#
# Data untuk Minggu ke-9:
#       order_details_id  order_id order_date pizza_size  \
# 7190              7191      3171 2015-02-23          L
# 7191              7192      3172 2015-02-23          L
# 7192              7193      3172 2015-02-23          S
# 7193              7194      3173 2015-02-23          S
# 7194              7195      3173 2015-02-23          M
# ...                ...       ...        ...        ...
# 8142              8143      3576 2015-03-01          S
# 8143              8144      3577 2015-03-01          L
# 8144              8145      3578 2015-03-01          M
# 8145              8146      3579 2015-03-01          S
# 8146              8147      3579 2015-03-01          S
#
#                         pizza_name  week_number
# 7190         The Soppressata Pizza            9
# 7191    The Barbecue Chicken Pizza            9
# 7192      The Classic Deluxe Pizza            9
# 7193  The California Chicken Pizza            9
# 7194          The Napolitana Pizza            9
# ...                            ...          ...
# 8142        The Thai Chicken Pizza            9
# 8143   The Southwest Chicken Pizza            9
# 8144  The California Chicken Pizza            9
# 8145            The Big Meat Pizza            9
# 8146      The Classic Deluxe Pizza            9
#
# [957 rows x 6 columns]
#
#
# Data untuk Minggu ke-10:
#       order_details_id  order_id order_date pizza_size  \
# 8147              8148      3580 2015-03-02          S
# 8148              8149      3581 2015-03-02          M
# 8149              8150      3582 2015-03-02          M
# 8150              8151      3582 2015-03-02          M
# 8151              8152      3583 2015-03-02          S
# ...                ...       ...        ...        ...
# 9113              9114      3997 2015-03-08          L
# 9114              9115      3998 2015-03-08          M
# 9115              9116      3999 2015-03-08          M
# 9116              9117      3999 2015-03-08          M
# 9117              9118      3999 2015-03-08          S
#
#                                       pizza_name  week_number
# 8147  The Pepperoni, Mushroom, and Peppers Pizza           10
# 8148                   The Chicken Alfredo Pizza           10
# 8149            The Prosciutto and Arugula Pizza           10
# 8150                     The Spicy Italian Pizza           10
# 8151                  The Barbecue Chicken Pizza           10
# ...                                          ...          ...
# 9113                     The Chicken Pesto Pizza           10
# 9114                      The Thai Chicken Pizza           10
# 9115                   The Chicken Alfredo Pizza           10
# 9116                    The Classic Deluxe Pizza           10
# 9117                     The Mediterranean Pizza           10
#
# [971 rows x 6 columns]
#
#
# Data untuk Minggu ke-11:
#        order_details_id  order_id order_date pizza_size  \
# 9118               9119      4000 2015-03-09          L
# 9119               9120      4000 2015-03-09          L
# 9120               9121      4000 2015-03-09          L
# 9121               9122      4000 2015-03-09          L
# 9122               9123      4001 2015-03-09          S
# ...                 ...       ...        ...        ...
# 10057             10058      4401 2015-03-15          L
# 10058             10059      4401 2015-03-15          M
# 10059             10060      4402 2015-03-15          M
# 10060             10061      4403 2015-03-15          S
# 10061             10062      4403 2015-03-15          S
#
#                        pizza_name  week_number
# 9118   The Barbecue Chicken Pizza           11
# 9119       The Green Garden Pizza           11
# 9120        The Soppressata Pizza           11
# 9121       The Thai Chicken Pizza           11
# 9122      The Mediterranean Pizza           11
# ...                           ...          ...
# 10057      The Thai Chicken Pizza           11
# 10058      The Thai Chicken Pizza           11
# 10059          The Hawaiian Pizza           11
# 10060    The Classic Deluxe Pizza           11
# 10061          The Hawaiian Pizza           11
#
# [944 rows x 6 columns]
#
#
# Data untuk Minggu ke-12:
#        order_details_id  order_id order_date pizza_size  \
# 10062             10063      4404 2015-03-16          S
# 10063             10064      4404 2015-03-16          L
# 10064             10065      4405 2015-03-16          S
# 10065             10066      4405 2015-03-16          S
# 10066             10067      4406 2015-03-16          L
# ...                 ...       ...        ...        ...
# 10993             10994      4817 2015-03-22          M
# 10994             10995      4817 2015-03-22          M
# 10995             10996      4818 2015-03-22          S
# 10996             10997      4819 2015-03-22          L
# 10997             10998      4819 2015-03-22          L
#
#                              pizza_name  week_number
# 10062              The Napolitana Pizza           12
# 10063           The Spicy Italian Pizza           12
# 10064                The Big Meat Pizza           12
# 10065       The Italian Capocollo Pizza           12
# 10066           The Pepper Salami Pizza           12
# ...                                 ...          ...
# 10993           The Chicken Pesto Pizza           12
# 10994           The Mediterranean Pizza           12
# 10995  The Prosciutto and Arugula Pizza           12
# 10996        The Spinach and Feta Pizza           12
# 10997            The Thai Chicken Pizza           12
#
# [936 rows x 6 columns]
#
#
# Data untuk Minggu ke-13:
#        order_details_id  order_id order_date pizza_size  \
# 10998             10999      4820 2015-03-23          L
# 10999             11000      4821 2015-03-23          S
# 11000             11001      4821 2015-03-23          M
# 11001             11002      4821 2015-03-23          S
# 11002             11003      4822 2015-03-23          L
# ...                 ...       ...        ...        ...
# 11937             11938      5244 2015-03-29          L
# 11938             11939      5244 2015-03-29          L
# 11939             11940      5244 2015-03-29          M
# 11940             11941      5245 2015-03-29          M
# 11941             11942      5246 2015-03-29          S
#
#                              pizza_name  week_number
# 10998                The Mexicana Pizza           13
# 10999                The Hawaiian Pizza           13
# 11000               The Pepperoni Pizza           13
# 11001         The Spinach Supreme Pizza           13
# 11002          The Classic Deluxe Pizza           13
# ...                                 ...          ...
# 11937        The Barbecue Chicken Pizza           13
# 11938             The Five Cheese Pizza           13
# 11939       The Italian Capocollo Pizza           13
# 11940  The Prosciutto and Arugula Pizza           13
# 11941               The Pepperoni Pizza           13
#
# [944 rows x 6 columns]
#
#
# Data untuk Minggu ke-14:
#        order_details_id  order_id order_date pizza_size  \
# 11942             11943      5247 2015-03-30          M
# 11943             11944      5247 2015-03-30          L
# 11944             11945      5247 2015-03-30          S
# 11945             11946      5248 2015-03-30          L
# 11946             11947      5248 2015-03-30          S
# ...                 ...       ...        ...        ...
# 12938             12939      5677 2015-04-05          M
# 12939             12940      5677 2015-04-05          S
# 12940             12941      5677 2015-04-05          L
# 12941             12942      5678 2015-04-05          S
# 12942             12943      5679 2015-04-05          L
#
#                                        pizza_name  week_number
# 11942                The California Chicken Pizza           14
# 11943                   The Chicken Alfredo Pizza           14
# 11944                     The Chicken Pesto Pizza           14
# 11945                  The Barbecue Chicken Pizza           14
# 11946                      The Green Garden Pizza           14
# ...                                           ...          ...
# 12938                The Italian Vegetables Pizza           14
# 12939  The Pepperoni, Mushroom, and Peppers Pizza           14
# 12940                 The Southwest Chicken Pizza           14
# 12941                   The Spinach Supreme Pizza           14
# 12942           The Vegetables + Vegetables Pizza           14
#
# [1001 rows x 6 columns]
#
#
# Data untuk Minggu ke-15:
#        order_details_id  order_id order_date pizza_size  \
# 12943             12944      5680 2015-04-06          S
# 12944             12945      5680 2015-04-06          L
# 12945             12946      5681 2015-04-06          L
# 12946             12947      5682 2015-04-06          L
# 12947             12948      5683 2015-04-06          L
# ...                 ...       ...        ...        ...
# 13887             13888      6086 2015-04-12          M
# 13888             13889      6087 2015-04-12          L
# 13889             13890      6087 2015-04-12          L
# 13890             13891      6087 2015-04-12          S
# 13891             13892      6087 2015-04-12          M
#
#                       pizza_name  week_number
# 12943   The Classic Deluxe Pizza           15
# 12944      The Soppressata Pizza           15
# 12945      The Five Cheese Pizza           15
# 12946     The Thai Chicken Pizza           15
# 12947  The Italian Supreme Pizza           15
# ...                          ...          ...
# 13887   The Classic Deluxe Pizza           15
# 13888    The Chicken Pesto Pizza           15
# 13889  The Italian Supreme Pizza           15
# 13890      The Soppressata Pizza           15
# 13891    The Spinach Pesto Pizza           15
#
# [949 rows x 6 columns]
#
#
# Data untuk Minggu ke-16:
#        order_details_id  order_id order_date pizza_size  \
# 13892             13893      6088 2015-04-13          M
# 13893             13894      6088 2015-04-13          S
# 13894             13895      6089 2015-04-13          L
# 13895             13896      6089 2015-04-13          S
# 13896             13897      6089 2015-04-13          S
# ...                 ...       ...        ...        ...
# 14839             14840      6498 2015-04-19          L
# 14840             14841      6499 2015-04-19          M
# 14841             14842      6500 2015-04-19          M
# 14842             14843      6500 2015-04-19          M
# 14843             14844      6501 2015-04-19          M
#
#                                        pizza_name  week_number
# 13892  The Pepperoni, Mushroom, and Peppers Pizza           16
# 13893                      The Thai Chicken Pizza           16
# 13894                  The Barbecue Chicken Pizza           16
# 13895                      The Green Garden Pizza           16
# 13896                         The Pepperoni Pizza           16
# ...                                           ...          ...
# 14839                          The Hawaiian Pizza           16
# 14840                The California Chicken Pizza           16
# 14841            The Prosciutto and Arugula Pizza           16
# 14842           The Vegetables + Vegetables Pizza           16
# 14843                The California Chicken Pizza           16
#
# [952 rows x 6 columns]
#
#
# Data untuk Minggu ke-17:
#        order_details_id  order_id order_date pizza_size  \
# 14844             14845      6502 2015-04-20          L
# 14845             14846      6502 2015-04-20          S
# 14846             14847      6503 2015-04-20          M
# 14847             14848      6504 2015-04-20          L
# 14848             14849      6505 2015-04-20          S
# ...                 ...       ...        ...        ...
# 15792             15793      6935 2015-04-26          M
# 15793             15794      6936 2015-04-26          M
# 15794             15795      6936 2015-04-26          S
# 15795             15796      6937 2015-04-26          L
# 15796             15797      6938 2015-04-26          M
#
#                               pizza_name  week_number
# 14844          The Spinach Supreme Pizza           17
# 14845          The Spinach Supreme Pizza           17
# 14846         The Spinach and Feta Pizza           17
# 14847  The Vegetables + Vegetables Pizza           17
# 14848  The Vegetables + Vegetables Pizza           17
# ...                                  ...          ...
# 15792       The Italian Vegetables Pizza           17
# 15793         The Barbecue Chicken Pizza           17
# 15794        The Southwest Chicken Pizza           17
# 15795             The Thai Chicken Pizza           17
# 15796                 The Mexicana Pizza           17
#
# [953 rows x 6 columns]
#
#
# Data untuk Minggu ke-18:
#        order_details_id  order_id order_date pizza_size  \
# 15797             15798      6939 2015-04-27          S
# 15798             15799      6939 2015-04-27          S
# 15799             15800      6940 2015-04-27          S
# 15800             15801      6941 2015-04-27          S
# 15801             15802      6942 2015-04-27          L
# ...                 ...       ...        ...        ...
# 16710             16711      7359 2015-05-03          L
# 16711             16712      7360 2015-05-03          L
# 16712             16713      7360 2015-05-03          L
# 16713             16714      7361 2015-05-03          M
# 16714             16715      7361 2015-05-03          M
#
#                                        pizza_name  week_number
# 15797                  The Barbecue Chicken Pizza           18
# 15798                          The Hawaiian Pizza           18
# 15799            The Prosciutto and Arugula Pizza           18
# 15800                          The Big Meat Pizza           18
# 15801                       The Four Cheese Pizza           18
# ...                                           ...          ...
# 16710                     The Spicy Italian Pizza           18
# 16711                   The Italian Supreme Pizza           18
# 16712           The Vegetables + Vegetables Pizza           18
# 16713  The Pepperoni, Mushroom, and Peppers Pizza           18
# 16714                         The Pepperoni Pizza           18
#
# [918 rows x 6 columns]
#
#
# Data untuk Minggu ke-19:
#        order_details_id  order_id order_date pizza_size  \
# 16715             16716      7362 2015-05-04          L
# 16716             16717      7362 2015-05-04          S
# 16717             16718      7363 2015-05-04          M
# 16718             16719      7363 2015-05-04          L
# 16719             16720      7363 2015-05-04          M
# ...                 ...       ...        ...        ...
# 17673             17674      7759 2015-05-10          L
# 17674             17675      7760 2015-05-10          M
# 17675             17676      7760 2015-05-10          S
# 17676             17677      7760 2015-05-10          S
# 17677             17678      7760 2015-05-10          L
#
#                               pizza_name  week_number
# 16715          The Italian Supreme Pizza           19
# 16716              The Soppressata Pizza           19
# 16717         The Barbecue Chicken Pizza           19
# 16718                 The Hawaiian Pizza           19
# 16719        The Italian Capocollo Pizza           19
# ...                                  ...          ...
# 17673               The Napolitana Pizza           19
# 17674       The California Chicken Pizza           19
# 17675                 The Sicilian Pizza           19
# 17676             The Thai Chicken Pizza           19
# 17677  The Vegetables + Vegetables Pizza           19
#
# [963 rows x 6 columns]
#
#
# Data untuk Minggu ke-20:
#        order_details_id  order_id order_date pizza_size  \
# 17678             17679      7761 2015-05-11          S
# 17679             17680      7762 2015-05-11          M
# 17680             17681      7763 2015-05-11          S
# 17681             17682      7763 2015-05-11          M
# 17682             17683      7764 2015-05-11          L
# ...                 ...       ...        ...        ...
# 18700             18701      8216 2015-05-17          S
# 18701             18702      8217 2015-05-17          L
# 18702             18703      8217 2015-05-17          M
# 18703             18704      8218 2015-05-17          S
# 18704             18705      8218 2015-05-17          L
#
#                          pizza_name  week_number
# 17678  The California Chicken Pizza           20
# 17679    The Barbecue Chicken Pizza           20
# 17680      The Classic Deluxe Pizza           20
# 17681         The Four Cheese Pizza           20
# 17682  The California Chicken Pizza           20
# ...                             ...          ...
# 18700    The Spinach and Feta Pizza           20
# 18701       The Chicken Pesto Pizza           20
# 18702     The Italian Supreme Pizza           20
# 18703           The Pepperoni Pizza           20
# 18704       The Pepper Salami Pizza           20
#
# [1027 rows x 6 columns]
#
#
# Data untuk Minggu ke-21:
#        order_details_id  order_id order_date pizza_size  \
# 18705             18706      8219 2015-05-18          S
# 18706             18707      8219 2015-05-18          M
# 18707             18708      8219 2015-05-18          M
# 18708             18709      8219 2015-05-18          M
# 18709             18710      8220 2015-05-18          L
# ...                 ...       ...        ...        ...
# 19626             19627      8630 2015-05-24          L
# 19627             19628      8631 2015-05-24          M
# 19628             19629      8632 2015-05-24          M
# 19629             19630      8632 2015-05-24          S
# 19630             19631      8632 2015-05-24          S
#
#                        pizza_name  week_number
# 18705          The Big Meat Pizza           21
# 18706         The Calabrese Pizza           21
# 18707          The Mexicana Pizza           21
# 18708      The Thai Chicken Pizza           21
# 18709  The Barbecue Chicken Pizza           21
# ...                           ...          ...
# 19626      The Thai Chicken Pizza           21
# 19627  The Barbecue Chicken Pizza           21
# 19628          The Mexicana Pizza           21
# 19629  The Spinach and Feta Pizza           21
# 19630      The Thai Chicken Pizza           21
#
# [926 rows x 6 columns]
#
#
# Data untuk Minggu ke-22:
#        order_details_id  order_id order_date pizza_size  \
# 19631             19632      8633 2015-05-25          L
# 19632             19633      8634 2015-05-25          M
# 19633             19634      8635 2015-05-25          L
# 19634             19635      8636 2015-05-25          L
# 19635             19636      8636 2015-05-25          L
# ...                 ...       ...        ...        ...
# 20535             20536      9019 2015-05-31          L
# 20536             20537      9020 2015-05-31          S
# 20537             20538      9020 2015-05-31          L
# 20538             20539      9021 2015-05-31          L
# 20539             20540      9022 2015-05-31          L
#
#                                        pizza_name  week_number
# 19631                          The Sicilian Pizza           22
# 19632                          The Sicilian Pizza           22
# 19633                 The Southwest Chicken Pizza           22
# 19634                 The Italian Capocollo Pizza           22
# 19635  The Pepperoni, Mushroom, and Peppers Pizza           22
# ...                                           ...          ...
# 20535                     The Chicken Pesto Pizza           22
# 20536                          The Big Meat Pizza           22
# 20537                          The Mexicana Pizza           22
# 20538                   The Italian Supreme Pizza           22
# 20539                   The Italian Supreme Pizza           22
#
# [909 rows x 6 columns]
#
#
# Data untuk Minggu ke-23:
#        order_details_id  order_id order_date pizza_size  \
# 20540             20541      9023 2015-06-01          M
# 20541             20542      9024 2015-06-01          M
# 20542             20543      9025 2015-06-01          M
# 20543             20544      9026 2015-06-01          S
# 20544             20545      9026 2015-06-01          S
# ...                 ...       ...        ...        ...
# 21518             21519      9444 2015-06-07          L
# 21519             21520      9445 2015-06-07          S
# 21520             21521      9445 2015-06-07          L
# 21521             21522      9445 2015-06-07          L
# 21522             21523      9445 2015-06-07          L
#
#                               pizza_name  week_number
# 20540             The Green Garden Pizza           23
# 20541  The Vegetables + Vegetables Pizza           23
# 20542         The Barbecue Chicken Pizza           23
# 20543         The Barbecue Chicken Pizza           23
# 20544                The Pepperoni Pizza           23
# ...                                  ...          ...
# 21518        The Italian Capocollo Pizza           23
# 21519         The Barbecue Chicken Pizza           23
# 21520        The Italian Capocollo Pizza           23
# 21521            The Pepper Salami Pizza           23
# 21522             The Thai Chicken Pizza           23
#
# [983 rows x 6 columns]
#
#
# Data untuk Minggu ke-24:
#        order_details_id  order_id order_date pizza_size  \
# 21523             21524      9446 2015-06-08          L
# 21524             21525      9446 2015-06-08          L
# 21525             21526      9447 2015-06-08          M
# 21526             21527      9448 2015-06-08          S
# 21527             21528      9448 2015-06-08          L
# ...                 ...       ...        ...        ...
# 22449             22450      9861 2015-06-14          S
# 22450             22451      9862 2015-06-14          M
# 22451             22452      9862 2015-06-14          L
# 22452             22453      9862 2015-06-14          M
# 22453             22454      9863 2015-06-14          M
#
#                               pizza_name  week_number
# 21523       The California Chicken Pizza           24
# 21524                 The Hawaiian Pizza           24
# 21525        The Southwest Chicken Pizza           24
# 21526                 The Big Meat Pizza           24
# 21527              The Four Cheese Pizza           24
# ...                                  ...          ...
# 22449  The Vegetables + Vegetables Pizza           24
# 22450         The Barbecue Chicken Pizza           24
# 22451            The Mediterranean Pizza           24
# 22452   The Prosciutto and Arugula Pizza           24
# 22453         The Barbecue Chicken Pizza           24
#
# [931 rows x 6 columns]
#
#
# Data untuk Minggu ke-25:
#        order_details_id  order_id order_date pizza_size  \
# 22454             22455      9864 2015-06-15          L
# 22455             22456      9864 2015-06-15          L
# 22456             22457      9865 2015-06-15          S
# 22457             22458      9866 2015-06-15          S
# 22458             22459      9866 2015-06-15          L
# ...                 ...       ...        ...        ...
# 23355             23356     10272 2015-06-21          S
# 23356             23357     10272 2015-06-21          M
# 23357             23358     10273 2015-06-21          S
# 23358             23359     10273 2015-06-21          L
# 23359             23360     10273 2015-06-21          M
#
#                               pizza_name  week_number
# 22454                 The Hawaiian Pizza           25
# 22455             The Thai Chicken Pizza           25
# 22456          The Spinach Supreme Pizza           25
# 22457         The Barbecue Chicken Pizza           25
# 22458              The Four Cheese Pizza           25
# ...                                  ...          ...
# 23355   The Prosciutto and Arugula Pizza           25
# 23356  The Vegetables + Vegetables Pizza           25
# 23357                 The Big Meat Pizza           25
# 23358              The Five Cheese Pizza           25
# 23359                The Pepperoni Pizza           25
#
# [906 rows x 6 columns]
#
#
# Data untuk Minggu ke-26:
#        order_details_id  order_id order_date pizza_size  \
# 23360             23361     10274 2015-06-22          S
# 23361             23362     10274 2015-06-22          L
# 23362             23363     10274 2015-06-22          S
# 23363             23364     10274 2015-06-22          S
# 23364             23365     10275 2015-06-22         XL
# ...                 ...       ...        ...        ...
# 24316             24317     10687 2015-06-28          L
# 24317             24318     10688 2015-06-28          L
# 24318             24319     10688 2015-06-28          S
# 24319             24320     10688 2015-06-28          L
# 24320             24321     10689 2015-06-28          M
#
#                              pizza_name  week_number
# 23360                The Big Meat Pizza           26
# 23361         The Italian Supreme Pizza           26
# 23362               The Pepperoni Pizza           26
# 23363           The Spinach Pesto Pizza           26
# 23364                   The Greek Pizza           26
# ...                                 ...          ...
# 24316  The Prosciutto and Arugula Pizza           26
# 24317           The Chicken Pesto Pizza           26
# 24318       The Italian Capocollo Pizza           26
# 24319           The Spicy Italian Pizza           26
# 24320         The Italian Supreme Pizza           26
#
# [961 rows x 6 columns]
#
#
# Data untuk Minggu ke-27:
#        order_details_id  order_id order_date pizza_size  \
# 24321             24322     10690 2015-06-29          M
# 24322             24323     10691 2015-06-29          S
# 24323             24324     10692 2015-06-29          M
# 24324             24325     10692 2015-06-29          M
# 24325             24326     10692 2015-06-29          S
# ...                 ...       ...        ...        ...
# 25364             25365     11162 2015-07-05          M
# 25365             25366     11163 2015-07-05          M
# 25366             25367     11163 2015-07-05          S
# 25367             25368     11163 2015-07-05          S
# 25368             25369     11163 2015-07-05          L
#
#                          pizza_name  week_number
# 24321  The California Chicken Pizza           27
# 24322        The Thai Chicken Pizza           27
# 24323      The Classic Deluxe Pizza           27
# 24324            The Sicilian Pizza           27
# 24325   The Southwest Chicken Pizza           27
# ...                             ...          ...
# 25364    The Spinach and Feta Pizza           27
# 25365  The California Chicken Pizza           27
# 25366        The Green Garden Pizza           27
# 25367          The Napolitana Pizza           27
# 25368        The Thai Chicken Pizza           27
#
# [1048 rows x 6 columns]
#
#
# Data untuk Minggu ke-28:
#        order_details_id  order_id order_date pizza_size  \
# 25369             25370     11164 2015-07-06          L
# 25370             25371     11164 2015-07-06          M
# 25371             25372     11164 2015-07-06          L
# 25372             25373     11165 2015-07-06          L
# 25373             25374     11165 2015-07-06          M
# ...                 ...       ...        ...        ...
# 26296             26297     11579 2015-07-12          L
# 26297             26298     11579 2015-07-12          S
# 26298             26299     11579 2015-07-12          S
# 26299             26300     11580 2015-07-12          L
# 26300             26301     11580 2015-07-12          M
#
#                              pizza_name  week_number
# 25369          The Classic Deluxe Pizza           28
# 25370          The Classic Deluxe Pizza           28
# 25371  The Prosciutto and Arugula Pizza           28
# 25372             The Five Cheese Pizza           28
# 25373           The Spicy Italian Pizza           28
# ...                                 ...          ...
# 26296             The Four Cheese Pizza           28
# 26297       The Italian Capocollo Pizza           28
# 26298         The Italian Supreme Pizza           28
# 26299         The Italian Supreme Pizza           28
# 26300  The Prosciutto and Arugula Pizza           28
#
# [932 rows x 6 columns]
#
#
# Data untuk Minggu ke-29:
#        order_details_id  order_id order_date pizza_size  \
# 26301             26302     11581 2015-07-13          L
# 26302             26303     11581 2015-07-13          L
# 26303             26304     11582 2015-07-13          S
# 26304             26305     11583 2015-07-13          L
# 26305             26306     11583 2015-07-13          S
# ...                 ...       ...        ...        ...
# 27259             27260     11997 2015-07-19          S
# 27260             27261     11998 2015-07-19          L
# 27261             27262     11999 2015-07-19          M
# 27262             27263     11999 2015-07-19          S
# 27263             27264     12000 2015-07-19          L
#
#                                        pizza_name  week_number
# 26301                The Italian Vegetables Pizza           29
# 26302            The Prosciutto and Arugula Pizza           29
# 26303  The Pepperoni, Mushroom, and Peppers Pizza           29
# 26304                The California Chicken Pizza           29
# 26305                        The Napolitana Pizza           29
# ...                                           ...          ...
# 27259  The Pepperoni, Mushroom, and Peppers Pizza           29
# 27260                          The Sicilian Pizza           29
# 27261                        The Napolitana Pizza           29
# 27262                       The Soppressata Pizza           29
# 27263                        The Napolitana Pizza           29
#
# [963 rows x 6 columns]
#
#
# Data untuk Minggu ke-30:
#        order_details_id  order_id order_date pizza_size  \
# 27264             27265     12001 2015-07-20          M
# 27265             27266     12002 2015-07-20          L
# 27266             27267     12002 2015-07-20          L
# 27267             27268     12003 2015-07-20          M
# 27268             27269     12003 2015-07-20          L
# ...                 ...       ...        ...        ...
# 28216             28217     12432 2015-07-26          L
# 28217             28218     12432 2015-07-26          L
# 28218             28219     12432 2015-07-26          M
# 28219             28220     12433 2015-07-26          M
# 28220             28221     12433 2015-07-26          M
#
#                               pizza_name  week_number
# 27264        The Southwest Chicken Pizza           30
# 27265                 The Hawaiian Pizza           30
# 27266             The Thai Chicken Pizza           30
# 27267           The Classic Deluxe Pizza           30
# 27268                 The Hawaiian Pizza           30
# ...                                  ...          ...
# 28216                 The Mexicana Pizza           30
# 28217               The Napolitana Pizza           30
# 28218   The Prosciutto and Arugula Pizza           30
# 28219          The Spinach Supreme Pizza           30
# 28220  The Vegetables + Vegetables Pizza           30
#
# [957 rows x 6 columns]
#
#
# Data untuk Minggu ke-31:
#        order_details_id  order_id order_date pizza_size  \
# 28221             28222     12434 2015-07-27         XL
# 28222             28223     12435 2015-07-27          M
# 28223             28224     12436 2015-07-27          S
# 28224             28225     12436 2015-07-27          L
# 28225             28226     12437 2015-07-27          L
# ...                 ...       ...        ...        ...
# 29121             29122     12850 2015-08-02          L
# 29122             29123     12850 2015-08-02          S
# 29123             29124     12851 2015-08-02          S
# 29124             29125     12851 2015-08-02          M
# 29125             29126     12852 2015-08-02          L
#
#                         pizza_name  week_number
# 28221              The Greek Pizza           31
# 28222  The Italian Capocollo Pizza           31
# 28223         The Napolitana Pizza           31
# 28224       The Thai Chicken Pizza           31
# 28225   The Spinach and Feta Pizza           31
# ...                            ...          ...
# 29121      The Spicy Italian Pizza           31
# 29122              The Greek Pizza           31
# 29123           The Big Meat Pizza           31
# 29124           The Sicilian Pizza           31
# 29125    The Spinach Supreme Pizza           31
#
# [905 rows x 6 columns]
#
#
# Data untuk Minggu ke-32:
#        order_details_id  order_id order_date pizza_size  \
# 29126             29127     12853 2015-08-03          S
# 29127             29128     12854 2015-08-03          S
# 29128             29129     12855 2015-08-03          L
# 29129             29130     12856 2015-08-03          M
# 29130             29131     12856 2015-08-03          S
# ...                 ...       ...        ...        ...
# 30059             30060     13276 2015-08-09          M
# 30060             30061     13277 2015-08-09          L
# 30061             30062     13277 2015-08-09          S
# 30062             30063     13278 2015-08-09          L
# 30063             30064     13278 2015-08-09          L
#
#                              pizza_name  week_number
# 29126           The Spinach Pesto Pizza           32
# 29127  The Prosciutto and Arugula Pizza           32
# 29128        The Spinach and Feta Pizza           32
# 29129                The Mexicana Pizza           32
# 29130             The Soppressata Pizza           32
# ...                                 ...          ...
# 30059               The Pepperoni Pizza           32
# 30060                The Hawaiian Pizza           32
# 30061             The Soppressata Pizza           32
# 30062               The Calabrese Pizza           32
# 30063      The California Chicken Pizza           32
#
# [938 rows x 6 columns]
#
#
# Data untuk Minggu ke-33:
#        order_details_id  order_id order_date pizza_size  \
# 30064             30065     13279 2015-08-10          L
# 30065             30066     13280 2015-08-10          L
# 30066             30067     13281 2015-08-10          L
# 30067             30068     13282 2015-08-10          L
# 30068             30069     13283 2015-08-10          S
# ...                 ...       ...        ...        ...
# 31040             31041     13712 2015-08-16          M
# 31041             31042     13712 2015-08-16          M
# 31042             31043     13712 2015-08-16          L
# 31043             31044     13712 2015-08-16          L
# 31044             31045     13713 2015-08-16          M
#
#                              pizza_name  week_number
# 30064               The Pepperoni Pizza           33
# 30065           The Mediterranean Pizza           33
# 30066         The Italian Supreme Pizza           33
# 30067      The California Chicken Pizza           33
# 30068           The Mediterranean Pizza           33
# ...                                 ...          ...
# 31040  The Prosciutto and Arugula Pizza           33
# 31041                The Sicilian Pizza           33
# 31042           The Spinach Pesto Pizza           33
# 31043            The Thai Chicken Pizza           33
# 31044           The Pepper Salami Pizza           33
#
# [981 rows x 6 columns]
#
#
# Data untuk Minggu ke-34:
#        order_details_id  order_id order_date pizza_size  \
# 31045             31046     13714 2015-08-17          S
# 31046             31047     13714 2015-08-17          M
# 31047             31048     13714 2015-08-17          L
# 31048             31049     13714 2015-08-17          L
# 31049             31050     13715 2015-08-17          S
# ...                 ...       ...        ...        ...
# 31978             31979     14117 2015-08-23          M
# 31979             31980     14118 2015-08-23          S
# 31980             31981     14119 2015-08-23          S
# 31981             31982     14120 2015-08-23          L
# 31982             31983     14120 2015-08-23          M
#
#                               pizza_name  week_number
# 31045                 The Big Meat Pizza           34
# 31046       The California Chicken Pizza           34
# 31047          The Italian Supreme Pizza           34
# 31048                 The Mexicana Pizza           34
# ...
# 38136               The Pepperoni Pizza           42
# ...                                 ...          ...
# 39038      The Italian Vegetables Pizza           42
# 39039                The Big Meat Pizza           42
# 39040           The Chicken Pesto Pizza           42
# 39041               The Pepperoni Pizza           42
# 39042                   The Greek Pizza           42
#
# [911 rows x 6 columns]
#
#
# Data untuk Minggu ke-43:
#        order_details_id  order_id order_date pizza_size  \
# 39043             39044     17211 2015-10-20          L
# 39044             39045     17211 2015-10-20          M
# 39045             39046     17211 2015-10-20          M
# 39046             39047     17211 2015-10-20          S
# 39047             39048     17212 2015-10-20          L
# ...                 ...       ...        ...        ...
# 39900             39901     17560 2015-10-25          S
# 39901             39902     17561 2015-10-25          L
# 39902             39903     17561 2015-10-25          S
# 39903             39904     17562 2015-10-25          S
# 39904             39905     17562 2015-10-25          S
#
#                          pizza_name  week_number
# 39043            The Hawaiian Pizza           43
# 39044  The Italian Vegetables Pizza           43
# 39045   The Southwest Chicken Pizza           43
# 39046       The Spicy Italian Pizza           43
# 39047         The Five Cheese Pizza           43
# ...                             ...          ...
# 39900            The Hawaiian Pizza           43
# 39901            The Mexicana Pizza           43
# 39902   The Southwest Chicken Pizza           43
# 39903        The Green Garden Pizza           43
# 39904         The Soppressata Pizza           43
#
# [862 rows x 6 columns]
#
#
# Data untuk Minggu ke-44:
#        order_details_id  order_id order_date pizza_size  \
# 39905             39906     17563 2015-10-27          M
# 39906             39907     17563 2015-10-27          S
# 39907             39908     17563 2015-10-27          M
# 39908             39909     17563 2015-10-27          L
# 39909             39910     17564 2015-10-27          S
# ...                 ...       ...        ...        ...
# 40694             40695     17932 2015-11-01          L
# 40695             40696     17932 2015-11-01          L
# 40696             40697     17932 2015-11-01          L
# 40697             40698     17933 2015-11-01          M
# 40698             40699     17933 2015-11-01          S
#
#                         pizza_name  week_number
# 39905   The Barbecue Chicken Pizza           44
# 39906     The Classic Deluxe Pizza           44
# 39907           The Mexicana Pizza           44
# 39908      The Pepper Salami Pizza           44
# 39909           The Hawaiian Pizza           44
# ...                            ...          ...
# 40694        The Five Cheese Pizza           44
# 40695           The Mexicana Pizza           44
# 40696  The Southwest Chicken Pizza           44
# 40697    The Italian Supreme Pizza           44
# 40698      The Spinach Pesto Pizza           44
#
# [794 rows x 6 columns]
#
#
# Data untuk Minggu ke-45:
#        order_details_id  order_id order_date pizza_size  \
# 40699             40700     17934 2015-11-02          S
# 40700             40701     17934 2015-11-02          L
# 40701             40702     17935 2015-11-02          S
# 40702             40703     17936 2015-11-02          S
# 40703             40704     17937 2015-11-02          L
# ...                 ...       ...        ...        ...
# 41654             41655     18326 2015-11-08          L
# 41655             41656     18326 2015-11-08          S
# 41656             41657     18327 2015-11-08          L
# 41657             41658     18327 2015-11-08          L
# 41658             41659     18327 2015-11-08          L
#
#                                        pizza_name  week_number
# 40699                          The Sicilian Pizza           45
# 40700           The Vegetables + Vegetables Pizza           45
# 40701                  The Barbecue Chicken Pizza           45
# 40702                          The Big Meat Pizza           45
# 40703  The Pepperoni, Mushroom, and Peppers Pizza           45
# ...                                           ...          ...
# 41654                     The Spicy Italian Pizza           45
# 41655                             The Greek Pizza           45
# 41656                The California Chicken Pizza           45
# 41657                     The Pepper Salami Pizza           45
# 41658                      The Thai Chicken Pizza           45
#
# [960 rows x 6 columns]
#
#
# Data untuk Minggu ke-46:
#        order_details_id  order_id order_date pizza_size  \
# 41659             41660     18328 2015-11-09         XL
# 41660             41661     18329 2015-11-09          L
# 41661             41662     18330 2015-11-09          M
# 41662             41663     18331 2015-11-09          S
# 41663             41664     18332 2015-11-09          S
# ...                 ...       ...        ...        ...
# 42577             42578     18725 2015-11-15          S
# 42578             42579     18726 2015-11-15          S
# 42579             42580     18727 2015-11-15          L
# 42580             42581     18727 2015-11-15          L
# 42581             42582     18727 2015-11-15          M
#
#                        pizza_name  week_number
# 41659             The Greek Pizza           46
# 41660  The Barbecue Chicken Pizza           46
# 41661     The Spicy Italian Pizza           46
# 41662             The Greek Pizza           46
# 41663          The Sicilian Pizza           46
# ...                           ...          ...
# 42577          The Hawaiian Pizza           46
# 42578          The Big Meat Pizza           46
# 42579  The Barbecue Chicken Pizza           46
# 42580       The Five Cheese Pizza           46
# 42581          The Mexicana Pizza           46
#
# [923 rows x 6 columns]
#
#
# Data untuk Minggu ke-47:
#        order_details_id  order_id order_date pizza_size  \
# 42582             42583     18728 2015-11-16          L
# 42583             42584     18728 2015-11-16          L
# 42584             42585     18729 2015-11-16          M
# 42585             42586     18729 2015-11-16          L
# 42586             42587     18730 2015-11-16          L
# ...                 ...       ...        ...        ...
# 43465             43466     19118 2015-11-22          L
# 43466             43467     19118 2015-11-22          L
# 43467             43468     19119 2015-11-22          M
# 43468             43469     19119 2015-11-22          M
# 43469             43470     19119 2015-11-22          M
#
#                                        pizza_name  week_number
# 42582                       The Five Cheese Pizza           47
# 42583                     The Spicy Italian Pizza           47
# 42584                The California Chicken Pizza           47
# 42585                     The Spicy Italian Pizza           47
# 42586                      The Thai Chicken Pizza           47
# ...                                           ...          ...
# 43465                The California Chicken Pizza           47
# 43466                             The Greek Pizza           47
# 43467                        The Napolitana Pizza           47
# 43468  The Pepperoni, Mushroom, and Peppers Pizza           47
# 43469                     The Pepper Salami Pizza           47
#
# [888 rows x 6 columns]
#
#
# Data untuk Minggu ke-48:
#        order_details_id  order_id order_date pizza_size  \
# 43470             43471     19120 2015-11-23          S
# 43471             43472     19120 2015-11-23          S
# 43472             43473     19120 2015-11-23          S
# 43473             43474     19121 2015-11-23          L
# 43474             43475     19121 2015-11-23          M
# ...                 ...       ...        ...        ...
# 44624             44625     19609 2015-11-29          S
# 44625             44626     19609 2015-11-29          L
# 44626             44627     19609 2015-11-29          M
# 44627             44628     19610 2015-11-29          L
# 44628             44629     19610 2015-11-29          M
#
#                               pizza_name  week_number
# 43470       The Italian Vegetables Pizza           48
# 43471             The Thai Chicken Pizza           48
# 43472                    The Greek Pizza           48
# 43473                The Pepperoni Pizza           48
# 43474        The Southwest Chicken Pizza           48
# ...                                  ...          ...
# 44624               The Brie Carre Pizza           48
# 44625              The Four Cheese Pizza           48
# 44626        The Italian Capocollo Pizza           48
# 44627          The Italian Supreme Pizza           48
# 44628  The Vegetables + Vegetables Pizza           48
#
# [1159 rows x 6 columns]
#
#
# Data untuk Minggu ke-49:
#        order_details_id  order_id order_date pizza_size  \
# 44629             44630     19611 2015-11-30          S
# 44630             44631     19612 2015-11-30          M
# 44631             44632     19613 2015-11-30          L
# 44632             44633     19614 2015-11-30          S
# 44633             44634     19615 2015-11-30          S
# ...                 ...       ...        ...        ...
# 45620             45621     20032 2015-12-06          L
# 45621             45622     20033 2015-12-06          M
# 45622             45623     20033 2015-12-06          L
# 45623             45624     20034 2015-12-06          M
# 45624             45625     20034 2015-12-06          L
#
#                              pizza_name  week_number
# 44629              The Brie Carre Pizza           49
# 44630  The Prosciutto and Arugula Pizza           49
# 44631            The Thai Chicken Pizza           49
# 44632      The California Chicken Pizza           49
# 44633                The Big Meat Pizza           49
# ...                                 ...          ...
# 45620           The Spicy Italian Pizza           49
# 45621             The Soppressata Pizza           49
# 45622            The Thai Chicken Pizza           49
# 45623         The Italian Supreme Pizza           49
# 45624            The Thai Chicken Pizza           49
#
# [996 rows x 6 columns]
#
#
# Data untuk Minggu ke-50:
#        order_details_id  order_id order_date pizza_size  \
# 45625             45626     20035 2015-12-07          M
# 45626             45627     20036 2015-12-07          M
# 45627             45628     20036 2015-12-07          L
# 45628             45629     20037 2015-12-07          S
# 45629             45630     20037 2015-12-07          S
# ...                 ...       ...        ...        ...
# 46562             46563     20449 2015-12-13          L
# 46563             46564     20449 2015-12-13          M
# 46564             46565     20450 2015-12-13          M
# 46565             46566     20451 2015-12-13          M
# 46566             46567     20451 2015-12-13          L
#
#                               pizza_name  week_number
# 45625                The Calabrese Pizza           50
# 45626           The Classic Deluxe Pizza           50
# 45627          The Spinach Supreme Pizza           50
# 45628       The California Chicken Pizza           50
# 45629           The Classic Deluxe Pizza           50
# ...                                  ...          ...
# 46562              The Four Cheese Pizza           50
# 46563  The Vegetables + Vegetables Pizza           50
# 46564       The Italian Vegetables Pizza           50
# 46565       The California Chicken Pizza           50
# 46566            The Spinach Pesto Pizza           50
#
# [942 rows x 6 columns]
#
#
# Data untuk Minggu ke-51:
#        order_details_id  order_id order_date pizza_size  \
# 46567             46568     20452 2015-12-14          S
# 46568             46569     20453 2015-12-14          S
# 46569             46570     20454 2015-12-14          S
# 46570             46571     20455 2015-12-14          L
# 46571             46572     20456 2015-12-14          L
# ...                 ...       ...        ...        ...
# 47512             47513     20877 2015-12-20          L
# 47513             47514     20878 2015-12-20          S
# 47514             47515     20879 2015-12-20          L
# 47515             47516     20880 2015-12-20          L
# 47516             47517     20881 2015-12-20          M
#
#                          pizza_name  week_number
# 46567            The Sicilian Pizza           51
# 46568    The Barbecue Chicken Pizza           51
# 46569        The Thai Chicken Pizza           51
# 46570     The Spinach Supreme Pizza           51
# 46571       The Mediterranean Pizza           51
# ...                             ...          ...
# 47512      The Classic Deluxe Pizza           51
# 47513            The Big Meat Pizza           51
# 47514       The Chicken Pesto Pizza           51
# 47515       The Chicken Pesto Pizza           51
# 47516  The California Chicken Pizza           51
#
# [950 rows x 6 columns]
#
#
# Data untuk Minggu ke-52:
#        order_details_id  order_id order_date pizza_size  \
# 47517             47518     20882 2015-12-21          M
# 47518             47519     20883 2015-12-21          S
# 47519             47520     20883 2015-12-21          M
# 47520             47521     20884 2015-12-21          L
# 47521             47522     20884 2015-12-21          M
# ...                 ...       ...        ...        ...
# 48192             48193     21177 2015-12-27          S
# 48193             48194     21177 2015-12-27          L
# 48194             48195     21178 2015-12-27          M
# 48195             48196     21179 2015-12-27          M
# 48196             48197     21179 2015-12-27          L
#
#                      pizza_name  week_number
# 47517   The Pepper Salami Pizza           52
# 47518        The Big Meat Pizza           52
# 47519       The Calabrese Pizza           52
# 47520     The Four Cheese Pizza           52
# 47521     The Four Cheese Pizza           52
# ...                         ...          ...
# 48192        The Hawaiian Pizza           52
# 48193    The Thai Chicken Pizza           52
# 48194  The Classic Deluxe Pizza           52
# 48195       The Calabrese Pizza           52
# 48196     The Five Cheese Pizza           52
#
# [680 rows x 6 columns]
#
#
# Data untuk Minggu ke-53:
#        order_details_id  order_id order_date pizza_size  \
# 48197             48198     21180 2015-12-28          M
# 48198             48199     21181 2015-12-28          M
# 48199             48200     21182 2015-12-28          M
# 48200             48201     21183 2015-12-28          M
# 48201             48202     21184 2015-12-28          L
# ...                 ...       ...        ...        ...
# 48615             48616     21348 2015-12-31          M
# 48616             48617     21348 2015-12-31          L
# 48617             48618     21348 2015-12-31          S
# 48618             48619     21349 2015-12-31          L
# 48619             48620     21350 2015-12-31          S
#
#                              pizza_name  week_number
# 48197                   The Greek Pizza           53
# 48198          The Classic Deluxe Pizza           53
# 48199           The Pepper Salami Pizza           53
# 48200  The Prosciutto and Arugula Pizza           53
# 48201             The Five Cheese Pizza           53
# ...                                 ...          ...
# 48615         The Chicken Alfredo Pizza           53
# 48616             The Four Cheese Pizza           53
# 48617              The Napolitana Pizza           53
# 48618                The Mexicana Pizza           53
# 48619        The Barbecue Chicken Pizza           53
#
# [423 rows x 6 columns]

# %%
weekly_dataframes[1]
# Out:
#      order_details_id  order_id order_date pizza_size  \
# 0                   1         1 2015-01-01          M
# 1                   2         2 2015-01-01          M
# 2                   3         2 2015-01-01          L
# 3                   4         2 2015-01-01          L
# 4                   5         2 2015-01-01          M
# ..                ...       ...        ...        ...
# 576               577       252 2015-01-04          M
# 577               578       253 2015-01-04          S
# 578               579       254 2015-01-04          L
# 579               580       254 2015-01-04          S
# 580               581       254 2015-01-04          L
#
#                            pizza_name  week_number
# 0                  The Hawaiian Pizza            1
# 1            The Classic Deluxe Pizza            1
# 2               The Five Cheese Pizza            1
# 3           The Italian Supreme Pizza            1
# 4                  The Mexicana Pizza            1
# ..                                ...          ...
# 576  The Prosciutto and Arugula Pizza            1
# 577              The Brie Carre Pizza            1
# 578        The Barbecue Chicken Pizza            1
# 579              The Brie Carre Pizza            1
# 580             The Five Cheese Pizza            1
#
# [581 rows x 6 columns]

# %%
minggu1 = weekly_dataframes[1]['pizza_name'].value_counts().head(3)
minggu1
# Out:
# pizza_name
# The Barbecue Chicken Pizza    35
# The Italian Supreme Pizza     32
# The Thai Chicken Pizza        32
# Name: count, dtype: int64

# %%
minggu2 = weekly_dataframes[2]['pizza_name'].value_counts().head(3)
minggu2
# Out:
# pizza_name
# The Pepperoni Pizza         60
# The Classic Deluxe Pizza    50
# The Hawaiian Pizza          44
# Name: count, dtype: int64

# %%
# Perulangan untuk mendapatkan 3 pizza terlaris tiap minggu
top_pizzas_per_week = {}
for week in range(1, 54):  # Loop dari minggu ke-1 hingga ke-53
    if week in weekly_dataframes:  # Pastikan minggu tersebut ada di data
        top_pizzas = weekly_dataframes[week]['pizza_name'].value_counts().tail(3)
        top_pizzas_per_week[week] = top_pizzas

# Tampilkan hasil
for week, top_pizzas in top_pizzas_per_week.items():
    print(f"Top 3 pizza minggu ke-{week}:")
    print(top_pizzas)
    print("\n")
# Out:
# Top 3 pizza minggu ke-1:
# pizza_name
# The Mediterranean Pizza    6
# The Calabrese Pizza        4
# The Brie Carre Pizza       3
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-2:
# pizza_name
# The Pepperoni, Mushroom, and Peppers Pizza    18
# The Spinach Pesto Pizza                       14
# The Brie Carre Pizza                           8
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-3:
# pizza_name
# The Mediterranean Pizza      12
# The Chicken Alfredo Pizza    12
# The Brie Carre Pizza          4
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-4:
# pizza_name
# The Green Garden Pizza    14
# The Calabrese Pizza       14
# The Brie Carre Pizza      11
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-5:
# pizza_name
# The Green Garden Pizza     13
# The Brie Carre Pizza       11
# The Mediterranean Pizza    11
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-6:
# pizza_name
# The Green Garden Pizza     15
# The Brie Carre Pizza       15
# The Mediterranean Pizza    14
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-7:
# pizza_name
# The Spinach Supreme Pizza    13
# The Brie Carre Pizza         12
# The Mediterranean Pizza      11
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-8:
# pizza_name
# The Spinach Supreme Pizza    14
# The Chicken Alfredo Pizza    14
# The Brie Carre Pizza          9
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-9:
# pizza_name
# The Spinach Pesto Pizza      16
# The Chicken Alfredo Pizza    15
# The Brie Carre Pizza          6
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-10:
# pizza_name
# The Greek Pizza            15
# The Chicken Pesto Pizza    13
# The Brie Carre Pizza       10
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-11:
# pizza_name
# The Soppressata Pizza      15
# The Mediterranean Pizza    13
# The Brie Carre Pizza       13
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-12:
# pizza_name
# The Mediterranean Pizza    15
# The Calabrese Pizza        11
# The Brie Carre Pizza       10
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-13:
# pizza_name
# The Spinach Supreme Pizza    14
# The Calabrese Pizza          11
# The Brie Carre Pizza          7
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-14:
# pizza_name
# The Chicken Pesto Pizza    16
# The Spinach Pesto Pizza    12
# The Brie Carre Pizza       11
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-15:
# pizza_name
# The Chicken Pesto Pizza    18
# The Spinach Pesto Pizza    10
# The Brie Carre Pizza        4
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-16:
# pizza_name
# The Chicken Pesto Pizza      16
# The Chicken Alfredo Pizza    12
# The Brie Carre Pizza          7
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-17:
# pizza_name
# The Spinach Pesto Pizza      14
# The Chicken Alfredo Pizza    13
# The Brie Carre Pizza          7
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-18:
# pizza_name
# The Mediterranean Pizza    15
# The Soppressata Pizza      11
# The Brie Carre Pizza       10
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-19:
# pizza_name
# The Green Garden Pizza     17
# The Chicken Pesto Pizza    11
# The Brie Carre Pizza       11
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-20:
# pizza_name
# The Chicken Alfredo Pizza    17
# The Spinach Supreme Pizza    15
# The Brie Carre Pizza         14
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-21:
# pizza_name
# The Italian Vegetables Pizza    14
# The Soppressata Pizza           14
# The Brie Carre Pizza            11
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-22:
# pizza_name
# The Spinach Supreme Pizza    15
# The Spinach Pesto Pizza      14
# The Brie Carre Pizza          4
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-23:
# pizza_name
# The Italian Vegetables Pizza    15
# The Mediterranean Pizza         14
# The Brie Carre Pizza            12
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-24:
# pizza_name
# The Soppressata Pizza      16
# The Chicken Pesto Pizza    12
# The Brie Carre Pizza        5
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-25:
# pizza_name
# The Prosciutto and Arugula Pizza    19
# The Brie Carre Pizza                14
# The Italian Vegetables Pizza        13
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-26:
# pizza_name
# The Mediterranean Pizza    15
# The Green Garden Pizza     14
# The Brie Carre Pizza        7
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-27:
# pizza_name
# The Chicken Pesto Pizza      16
# The Chicken Alfredo Pizza    16
# The Brie Carre Pizza         10
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-28:
# pizza_name
# The Mediterranean Pizza         15
# The Brie Carre Pizza            11
# The Italian Vegetables Pizza     9
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-29:
# pizza_name
# The Calabrese Pizza        16
# The Spinach Pesto Pizza    14
# The Brie Carre Pizza       12
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-30:
# pizza_name
# The Spinach Pesto Pizza    15
# The Soppressata Pizza      13
# The Brie Carre Pizza        7
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-31:
# pizza_name
# The Chicken Alfredo Pizza       13
# The Italian Vegetables Pizza    11
# The Brie Carre Pizza            10
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-32:
# pizza_name
# The Italian Vegetables Pizza    15
# The Green Garden Pizza          13
# The Brie Carre Pizza             7
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-33:
# pizza_name
# The Spinach Pesto Pizza    14
# The Calabrese Pizza        14
# The Brie Carre Pizza       11
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-34:
# pizza_name
# The Green Garden Pizza     14
# The Chicken Pesto Pizza    13
# The Brie Carre Pizza        9
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-35:
# pizza_name
# The Mediterranean Pizza    13
# The Calabrese Pizza        11
# The Brie Carre Pizza        9
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-36:
# pizza_name
# The Italian Vegetables Pizza    13
# The Brie Carre Pizza            13
# The Calabrese Pizza             13
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-37:
# pizza_name
# The Spinach Supreme Pizza    14
# The Calabrese Pizza          14
# The Brie Carre Pizza         13
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-38:
# pizza_name
# The Green Garden Pizza    15
# The Soppressata Pizza     13
# The Brie Carre Pizza      10
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-39:
# pizza_name
# The Mediterranean Pizza    11
# The Chicken Pesto Pizza     9
# The Brie Carre Pizza        4
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-40:
# pizza_name
# The Mediterranean Pizza      16
# The Spinach Supreme Pizza    15
# The Brie Carre Pizza         11
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-41:
# pizza_name
# The Spinach Pesto Pizza      10
# The Brie Carre Pizza          8
# The Chicken Alfredo Pizza     7
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-42:
# pizza_name
# The Mediterranean Pizza    15
# The Spinach Pesto Pizza    13
# The Brie Carre Pizza        7
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-43:
# pizza_name
# The Chicken Pesto Pizza    12
# The Spinach Pesto Pizza    11
# The Brie Carre Pizza        8
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-44:
# pizza_name
# The Italian Vegetables Pizza    11
# The Spinach and Feta Pizza       9
# The Brie Carre Pizza             8
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-45:
# pizza_name
# The Italian Vegetables Pizza         14
# The Vegetables + Vegetables Pizza    14
# The Brie Carre Pizza                  7
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-46:
# pizza_name
# The Green Garden Pizza          13
# The Brie Carre Pizza            12
# The Italian Vegetables Pizza    12
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-47:
# pizza_name
# The Green Garden Pizza          14
# The Italian Vegetables Pizza    10
# The Brie Carre Pizza             8
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-48:
# pizza_name
# The Spinach Supreme Pizza    16
# The Chicken Pesto Pizza      14
# The Brie Carre Pizza         13
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-49:
# pizza_name
# The Green Garden Pizza    13
# The Calabrese Pizza       11
# The Brie Carre Pizza       8
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-50:
# pizza_name
# The Spinach Pesto Pizza    13
# The Mediterranean Pizza    11
# The Brie Carre Pizza        9
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-51:
# pizza_name
# The Calabrese Pizza       14
# The Green Garden Pizza    13
# The Brie Carre Pizza      10
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-52:
# pizza_name
# The Spinach Supreme Pizza    8
# The Soppressata Pizza        7
# The Brie Carre Pizza         5
# Name: count, dtype: int64
#
#
# Top 3 pizza minggu ke-53:
# pizza_name
# The Spinach Supreme Pizza    6
# The Calabrese Pizza          6
# The Brie Carre Pizza         4
# Name: count, dtype: int64

# %%
top_pizzas_per_week[53]
# Out:
# pizza_name
# The California Chicken Pizza    24
# The Classic Deluxe Pizza        24
# The Pepperoni Pizza             21
# Name: count, dtype: int64

# %%
weekly_dataframes[2]
# Out:
#       order_details_id  order_id order_date pizza_size  \
# 581                582       255 2015-01-05          L
# 582                583       255 2015-01-05          M
# 583                584       255 2015-01-05          L
# 584                585       255 2015-01-05          M
# 585                586       256 2015-01-05          L
# ...                ...       ...        ...        ...
# 1527              1528       679 2015-01-11          L
# 1528              1529       679 2015-01-11          L
# 1529              1530       680 2015-01-11          S
# 1530              1531       680 2015-01-11          M
# 1531              1532       681 2015-01-11          L
#
#                                       pizza_name  week_number
# 581                        The Five Cheese Pizza            2
# 582                       The Green Garden Pizza            2
# 583                           The Hawaiian Pizza            2
# 584                   The Spinach and Feta Pizza            2
# 585   The Pepperoni, Mushroom, and Peppers Pizza            2
# ...                                          ...          ...
# 1527                   The Italian Supreme Pizza            2
# 1528                     The Mediterranean Pizza            2
# 1529                     The Chicken Pesto Pizza            2
# 1530                          The Sicilian Pizza            2
# 1531                     The Pepper Salami Pizza            2
#
# [951 rows x 6 columns]

# %%
len(weekly_dataframes)
# Out:
# 53

# %%
start_date = '2015-01-01'
end_date = '2015-01-31'

# Memfilter data berdasarkan rentang tanggal
Januari = PilihKolom[(PilihKolom['order_date'] >= start_date) & (PilihKolom['order_date'] <= end_date)]

# %%
Januari
# Out:
#       order_details_id  order_id order_date pizza_size  \
# 0                    1         1 2015-01-01          M
# 1                    2         2 2015-01-01          M
# 2                    3         2 2015-01-01          L
# 3                    4         2 2015-01-01          L
# 4                    5         2 2015-01-01          M
# ...                ...       ...        ...        ...
# 4151              4152      1844 2015-01-31          S
# 4152              4153      1845 2015-01-31          L
# 4153              4154      1845 2015-01-31          L
# 4154              4155      1845 2015-01-31          S
# 4155              4156      1845 2015-01-31          M
#
#                              pizza_name  week_number
# 0                    The Hawaiian Pizza            1
# 1              The Classic Deluxe Pizza            1
# 2                 The Five Cheese Pizza            1
# 3             The Italian Supreme Pizza            1
# 4                    The Mexicana Pizza            1
# ...                                 ...          ...
# 4151          The Spinach Supreme Pizza            5
# 4152       The Italian Vegetables Pizza            5
# 4153            The Pepper Salami Pizza            5
# 4154              The Soppressata Pizza            5
# 4155  The Vegetables + Vegetables Pizza            5
#
# [4156 rows x 6 columns]

# %%
start_date = '2015-02-01'
end_date = '2015-02-28'

# Memfilter data berdasarkan rentang tanggal
Februari = PilihKolom[(PilihKolom['order_date'] >= start_date) & (PilihKolom['order_date'] <= end_date)]
Februari
# Out:
#       order_details_id  order_id order_date pizza_size  \
# 4156              4157      1846 2015-02-01          S
# 4157              4158      1847 2015-02-01          M
# 4158              4159      1848 2015-02-01          L
# 4159              4160      1848 2015-02-01          M
# 4160              4161      1849 2015-02-01          L
# ...                ...       ...        ...        ...
# 8043              8044      3529 2015-02-28          L
# 8044              8045      3529 2015-02-28          M
# 8045              8046      3530 2015-02-28          S
# 8046              8047      3530 2015-02-28          S
# 8047              8048      3530 2015-02-28          M
#
#                              pizza_name  week_number
# 4156                 The Big Meat Pizza            5
# 4157           The Classic Deluxe Pizza            5
# 4158           The Classic Deluxe Pizza            5
# 4159        The Italian Capocollo Pizza            5
# 4160              The Five Cheese Pizza            5
# ...                                 ...          ...
# 8043        The Italian Capocollo Pizza            9
# 8044            The Pepper Salami Pizza            9
# 8045           The Classic Deluxe Pizza            9
# 8046             The Green Garden Pizza            9
# 8047  The Vegetables + Vegetables Pizza            9
#
# [3892 rows x 6 columns]

# %%
start_date = '2015-03-01'
end_date = '2015-03-31'

# Memfilter data berdasarkan rentang tanggal
Maret = PilihKolom[(PilihKolom['order_date'] >= start_date) & (PilihKolom['order_date'] <= end_date)]
Maret
# Out:
#        order_details_id  order_id order_date pizza_size  \
# 8048               8049      3531 2015-03-01          M
# 8049               8050      3532 2015-03-01          S
# 8050               8051      3533 2015-03-01          L
# 8051               8052      3533 2015-03-01          M
# 8052               8053      3533 2015-03-01          L
# ...                 ...       ...        ...        ...
# 12229             12230      5369 2015-03-31          L
# 12230             12231      5369 2015-03-31          L
# 12231             12232      5369 2015-03-31          S
# 12232             12233      5369 2015-03-31          L
# 12233             12234      5370 2015-03-31          M
#
#                               pizza_name  week_number
# 8048                 The Pepperoni Pizza            9
# 8049         The Southwest Chicken Pizza            9
# 8050               The Four Cheese Pizza            9
# 8051           The Italian Supreme Pizza            9
# 8052   The Vegetables + Vegetables Pizza            9
# ...                                  ...          ...
# 12229                 The Hawaiian Pizza           14
# 12230                 The Mexicana Pizza           14
# 12231                 The Sicilian Pizza           14
# 12232            The Spicy Italian Pizza           14
# 12233            The Spicy Italian Pizza           14
#
# [4186 rows x 6 columns]

# %%
start_date = '2015-04-01'
end_date = '2015-04-30'

# Memfilter data berdasarkan rentang tanggal
April = PilihKolom[(PilihKolom['order_date'] >= start_date) & (PilihKolom['order_date'] <= end_date)]
April
# Out:
#        order_details_id  order_id order_date pizza_size  \
# 12234             12235      5371 2015-04-01          M
# 12235             12236      5371 2015-04-01          L
# 12236             12237      5372 2015-04-01          M
# 12237             12238      5372 2015-04-01          S
# 12238             12239      5373 2015-04-01          M
# ...                 ...       ...        ...        ...
# 16296             16297      7167 2015-04-30          S
# 16297             16298      7168 2015-04-30          L
# 16298             16299      7169 2015-04-30          S
# 16299             16300      7169 2015-04-30          L
# 16300             16301      7169 2015-04-30         XL
#
#                         pizza_name  week_number
# 12234           The Sicilian Pizza           14
# 12235        The Soppressata Pizza           14
# 12236          The Pepperoni Pizza           14
# 12237              The Greek Pizza           14
# 12238        The Four Cheese Pizza           14
# ...                            ...          ...
# 16296           The Sicilian Pizza           18
# 16297        The Five Cheese Pizza           18
# 16298       The Green Garden Pizza           18
# 16299  The Southwest Chicken Pizza           18
# 16300              The Greek Pizza           18
#
# [4067 rows x 6 columns]

# %%
start_date = '2015-05-01'
end_date = '2015-05-31'

# Memfilter data berdasarkan rentang tanggal
Mei = PilihKolom[(PilihKolom['order_date'] >= start_date) & (PilihKolom['order_date'] <= end_date)]
Mei
# Out:
#        order_details_id  order_id order_date pizza_size  \
# 16301             16302      7170 2015-05-01          M
# 16302             16303      7171 2015-05-01          S
# 16303             16304      7172 2015-05-01          S
# 16304             16305      7173 2015-05-01          L
# 16305             16306      7174 2015-05-01          M
# ...                 ...       ...        ...        ...
# 20535             20536      9019 2015-05-31          L
# 20536             20537      9020 2015-05-31          S
# 20537             20538      9020 2015-05-31          L
# 20538             20539      9021 2015-05-31          L
# 20539             20540      9022 2015-05-31          L
#
#                        pizza_name  week_number
# 16301    The Classic Deluxe Pizza           18
# 16302  The Barbecue Chicken Pizza           18
# 16303  The Barbecue Chicken Pizza           18
# 16304          The Mexicana Pizza           18
# 16305         The Calabrese Pizza           18
# ...                           ...          ...
# 20535     The Chicken Pesto Pizza           22
# 20536          The Big Meat Pizza           22
# 20537          The Mexicana Pizza           22
# 20538   The Italian Supreme Pizza           22
# 20539   The Italian Supreme Pizza           22
#
# [4239 rows x 6 columns]

# %%
start_date = '2015-06-01'
end_date = '2015-06-30'

# Memfilter data berdasarkan rentang tanggal
Juni = PilihKolom[(PilihKolom['order_date'] >= start_date) & (PilihKolom['order_date'] <= end_date)]
Juni
# Out:
#        order_details_id  order_id order_date pizza_size  \
# 20540             20541      9023 2015-06-01          M
# 20541             20542      9024 2015-06-01          M
# 20542             20543      9025 2015-06-01          M
# 20543             20544      9026 2015-06-01          S
# 20544             20545      9026 2015-06-01          S
# ...                 ...       ...        ...        ...
# 24560             24561     10794 2015-06-30          S
# 24561             24562     10794 2015-06-30          M
# 24562             24563     10794 2015-06-30          M
# 24563             24564     10794 2015-06-30          L
# 24564             24565     10795 2015-06-30          L
#
#                               pizza_name  week_number
# 20540             The Green Garden Pizza           23
# 20541  The Vegetables + Vegetables Pizza           23
# 20542         The Barbecue Chicken Pizza           23
# 20543         The Barbecue Chicken Pizza           23
# 20544                The Pepperoni Pizza           23
# ...                                  ...          ...
# 24560               The Brie Carre Pizza           27
# 24561          The Chicken Alfredo Pizza           27
# 24562   The Prosciutto and Arugula Pizza           27
# 24563            The Spicy Italian Pizza           27
# 24564              The Soppressata Pizza           27
#
# [4025 rows x 6 columns]

# %%
start_date = '2015-07-01'
end_date = '2015-07-31'

# Memfilter data berdasarkan rentang tanggal
Juli = PilihKolom[(PilihKolom['order_date'] >= start_date) & (PilihKolom['order_date'] <= end_date)]
Juli
# Out:
#        order_details_id  order_id order_date pizza_size  \
# 24565             24566     10796 2015-07-01          L
# 24566             24567     10796 2015-07-01          M
# 24567             24568     10796 2015-07-01          L
# 24568             24569     10796 2015-07-01          L
# 24569             24570     10796 2015-07-01          S
# ...                 ...       ...        ...        ...
# 28861             28862     12727 2015-07-31          S
# 28862             28863     12728 2015-07-31          S
# 28863             28864     12729 2015-07-31          M
# 28864             28865     12729 2015-07-31          S
# 28865             28866     12730 2015-07-31          S
#
#                              pizza_name  week_number
# 24565        The Barbecue Chicken Pizza           27
# 24566                The Hawaiian Pizza           27
# 24567         The Italian Supreme Pizza           27
# 24568  The Prosciutto and Arugula Pizza           27
# 24569           The Spinach Pesto Pizza           27
# ...                                 ...          ...
# 28861         The Spinach Supreme Pizza           31
# 28862              The Napolitana Pizza           31
# 28863         The Italian Supreme Pizza           31
# 28864               The Pepperoni Pizza           31
# 28865         The Spinach Supreme Pizza           31
#
# [4301 rows x 6 columns]

# %%
start_date = '2015-08-01'
end_date = '2015-08-31'

# Memfilter data berdasarkan rentang tanggal
Agustus = PilihKolom[(PilihKolom['order_date'] >= start_date) & (PilihKolom['order_date'] <= end_date)]
Agustus
# Out:
#        order_details_id  order_id order_date pizza_size  \
# 28866             28867     12731 2015-08-01          M
# 28867             28868     12731 2015-08-01          L
# 28868             28869     12731 2015-08-01          S
# 28869             28870     12731 2015-08-01          S
# 28870             28871     12732 2015-08-01          S
# ...                 ...       ...        ...        ...
# 32955             32956     14569 2015-08-31          M
# 32956             32957     14570 2015-08-31          M
# 32957             32958     14570 2015-08-31          L
# 32958             32959     14570 2015-08-31          M
# 32959             32960     14571 2015-08-31          S
#
#                                        pizza_name  week_number
# 28866                  The Barbecue Chicken Pizza           31
# 28867                   The Chicken Alfredo Pizza           31
# 28868                          The Sicilian Pizza           31
# 28869                     The Spicy Italian Pizza           31
# 28870  The Pepperoni, Mushroom, and Peppers Pizza           31
# ...                                           ...          ...
# 32955                         The Calabrese Pizza           36
# 32956                         The Calabrese Pizza           36
# 32957                     The Chicken Pesto Pizza           36
# 32958                   The Spinach Supreme Pizza           36
# 32959                     The Spinach Pesto Pizza           36
#
# [4094 rows x 6 columns]

# %%
start_date = '2015-09-01'
end_date = '2015-09-30'

# Memfilter data berdasarkan rentang tanggal
September = PilihKolom[(PilihKolom['order_date'] >= start_date) & (PilihKolom['order_date'] <= end_date)]
September
# Out:
#        order_details_id  order_id order_date pizza_size  \
# 32960             32961     14572 2015-09-01          L
# 32961             32962     14572 2015-09-01          L
# 32962             32963     14573 2015-09-01          S
# 32963             32964     14574 2015-09-01          L
# 32964             32965     14574 2015-09-01          L
# ...                 ...       ...        ...        ...
# 36774             36775     16231 2015-09-30          S
# 36775             36776     16231 2015-09-30          L
# 36776             36777     16231 2015-09-30          M
# 36777             36778     16232 2015-09-30          M
# 36778             36779     16232 2015-09-30          S
#
#                               pizza_name  week_number
# 32960        The Italian Capocollo Pizza           36
# 32961             The Thai Chicken Pizza           36
# 32962                 The Sicilian Pizza           36
# 32963         The Barbecue Chicken Pizza           36
# 32964                 The Sicilian Pizza           36
# ...                                  ...          ...
# 36774                 The Sicilian Pizza           40
# 36775            The Spinach Pesto Pizza           40
# 36776  The Vegetables + Vegetables Pizza           40
# 36777                The Calabrese Pizza           40
# 36778                 The Hawaiian Pizza           40
#
# [3819 rows x 6 columns]

# %%
start_date = '2015-10-01'
end_date = '2015-10-31'

# Memfilter data berdasarkan rentang tanggal
Oktober = PilihKolom[(PilihKolom['order_date'] >= start_date) & (PilihKolom['order_date'] <= end_date)]
Oktober
# Out:
#        order_details_id  order_id order_date pizza_size  \
# 36779             36780     16233 2015-10-01          M
# 36780             36781     16233 2015-10-01         XL
# 36781             36782     16234 2015-10-01          L
# 36782             36783     16234 2015-10-01          S
# 36783             36784     16235 2015-10-01          M
# ...                 ...       ...        ...        ...
# 40571             40572     17876 2015-10-31          L
# 40572             40573     17876 2015-10-31          S
# 40573             40574     17877 2015-10-31          S
# 40574             40575     17878 2015-10-31          M
# 40575             40576     17878 2015-10-31          M
#
#                                        pizza_name  week_number
# 36779  The Pepperoni, Mushroom, and Peppers Pizza           40
# 36780                             The Greek Pizza           40
# 36781                  The Spinach and Feta Pizza           40
# 36782                      The Thai Chicken Pizza           40
# 36783                   The Italian Supreme Pizza           40
# ...                                           ...          ...
# 40571                          The Mexicana Pizza           44
# 40572                   The Spinach Supreme Pizza           44
# 40573                      The Thai Chicken Pizza           44
# 40574                   The Italian Supreme Pizza           44
# 40575                 The Southwest Chicken Pizza           44
#
# [3797 rows x 6 columns]

# %%
start_date = '2015-11-01'
end_date = '2015-11-30'

# Memfilter data berdasarkan rentang tanggal
November = PilihKolom[(PilihKolom['order_date'] >= start_date) & (PilihKolom['order_date'] <= end_date)]
November
# Out:
#        order_details_id  order_id order_date pizza_size  \
# 40576             40577     17879 2015-11-01          M
# 40577             40578     17880 2015-11-01          S
# 40578             40579     17880 2015-11-01          L
# 40579             40580     17880 2015-11-01          M
# 40580             40581     17880 2015-11-01          S
# ...                 ...       ...        ...        ...
# 44756             44757     19668 2015-11-30          L
# 44757             44758     19669 2015-11-30          M
# 44758             44759     19670 2015-11-30          M
# 44759             44760     19670 2015-11-30          S
# 44760             44761     19670 2015-11-30          S
#
#                          pizza_name  week_number
# 40576     The Chicken Alfredo Pizza           44
# 40577            The Big Meat Pizza           44
# 40578  The California Chicken Pizza           44
# 40579  The California Chicken Pizza           44
# 40580        The Green Garden Pizza           44
# ...                             ...          ...
# 44756   The Southwest Chicken Pizza           49
# 44757      The Classic Deluxe Pizza           49
# 44758    The Barbecue Chicken Pizza           49
# 44759            The Big Meat Pizza           49
# 44760   The Southwest Chicken Pizza           49
#
# [4185 rows x 6 columns]

# %%
start_date = '2015-12-01'
end_date = '2015-12-30'

# Memfilter data berdasarkan rentang tanggal
Desember = PilihKolom[(PilihKolom['order_date'] >= start_date) & (PilihKolom['order_date'] <= end_date)]
Desember
# Out:
#        order_details_id  order_id order_date pizza_size  \
# 44761             44762     19671 2015-12-01          M
# 44762             44763     19671 2015-12-01          S
# 44763             44764     19672 2015-12-01          S
# 44764             44765     19673 2015-12-01          M
# 44765             44766     19674 2015-12-01          L
# ...                 ...       ...        ...        ...
# 48444             48445     21274 2015-12-30          M
# 48445             48446     21275 2015-12-30          L
# 48446             48447     21275 2015-12-30          S
# 48447             48448     21276 2015-12-30          M
# 48448             48449     21277 2015-12-30          L
#
#                              pizza_name  week_number
# 44761             The Four Cheese Pizza           49
# 44762           The Mediterranean Pizza           49
# 44763  The Prosciutto and Arugula Pizza           49
# 44764           The Chicken Pesto Pizza           49
# 44765             The Five Cheese Pizza           49
# ...                                 ...          ...
# 48444       The Southwest Chicken Pizza           53
# 48445        The Barbecue Chicken Pizza           53
# 48446      The Italian Vegetables Pizza           53
# 48447           The Spicy Italian Pizza           53
# 48448               The Pepperoni Pizza           53
#
# [3688 rows x 6 columns]

# %%
unique_counts1 = Januari['pizza_name'].value_counts().head(3)
unique_counts1
# Out:
# pizza_name
# The Pepperoni Pizza             235
# The Barbecue Chicken Pizza      206
# The California Chicken Pizza    197
# Name: count, dtype: int64

# %%
unique_counts2 = Februari['pizza_name'].value_counts().head(3)
unique_counts2
# Out:
# pizza_name
# The Pepperoni Pizza             201
# The California Chicken Pizza    200
# The Hawaiian Pizza              194
# Name: count, dtype: int64

# %%
unique_counts3 = Maret['pizza_name'].value_counts().head(3)
unique_counts3
# Out:
# pizza_name
# The Barbecue Chicken Pizza    229
# The Hawaiian Pizza            212
# The Thai Chicken Pizza        210
# Name: count, dtype: int64

# %%
unique_counts4 = April['pizza_name'].value_counts().head(3)
unique_counts4
# Out:
# pizza_name
# The Classic Deluxe Pizza      214
# The Hawaiian Pizza            213
# The Barbecue Chicken Pizza    208
# Name: count, dtype: int64

# %%
unique_counts5 = Mei['pizza_name'].value_counts().head(3)
unique_counts5
# Out:
# pizza_name
# The Pepperoni Pizza           238
# The Barbecue Chicken Pizza    220
# The Classic Deluxe Pizza      215
# Name: count, dtype: int64

# %%
unique_counts6 = Juni['pizza_name'].value_counts().head(3)
unique_counts6
# Out:
# pizza_name
# The California Chicken Pizza    216
# The Classic Deluxe Pizza        193
# The Barbecue Chicken Pizza      188
# Name: count, dtype: int64

# %%
unique_counts7 = Juli['pizza_name'].value_counts().head(3)
unique_counts7
# Out:
# pizza_name
# The Pepperoni Pizza           223
# The Classic Deluxe Pizza      222
# The Barbecue Chicken Pizza    217
# Name: count, dtype: int64

# %%
unique_counts8 = Agustus['pizza_name'].value_counts().head(3)
unique_counts8
# Out:
# pizza_name
# The California Chicken Pizza    225
# The Pepperoni Pizza             209
# The Classic Deluxe Pizza        205
# Name: count, dtype: int64

# %%
unique_counts9 = September['pizza_name'].value_counts().head(3)
unique_counts9
# Out:
# pizza_name
# The Classic Deluxe Pizza    201
# The Thai Chicken Pizza      199
# The Hawaiian Pizza          195
# Name: count, dtype: int64

# %%
unique_counts10 = Oktober['pizza_name'].value_counts().head(3)
unique_counts10
# Out:
# pizza_name
# The Classic Deluxe Pizza    193
# The Pepperoni Pizza         191
# The Thai Chicken Pizza      186
# Name: count, dtype: int64

# %%
unique_counts11 = November['pizza_name'].value_counts().head(3)
unique_counts11
# Out:
# pizza_name
# The Hawaiian Pizza            219
# The Classic Deluxe Pizza      217
# The Barbecue Chicken Pizza    211
# Name: count, dtype: int64

# %%
unique_counts12 = Desember['pizza_name'].value_counts().head(3)
unique_counts12
# Out:
# pizza_name
# The Hawaiian Pizza              202
# The Thai Chicken Pizza          198
# The California Chicken Pizza    194
# Name: count, dtype: int64

# %% [markdown]
# ## gak kepake

# %%
len(Mei['pizza_name'].unique())
# Out:
# 32

# %%
Mei.columns
# Out:
# Index(['order_details_id', 'order_id', 'order_date', 'pizza_size',
#        'pizza_name', 'week_number'],
#       dtype='object')

# %%
result = PilihKolom.groupby('order_id').agg({
    'pizza_size': '; '.join,  # Menggabungkan nama pizza
    # 'pizza_size': ', '.join   # Menggabungkan ukuran pizza 
}).reset_index()

result
# Out:
#        order_id     pizza_size
# 0             1              M
# 1             2  M; L; L; M; L
# 2             3           M; L
# 3             4              M
# 4             5              M
# ...         ...            ...
# 21345     21346     S; M; S; L
# 21346     21347     M; M; S; L
# 21347     21348        M; L; S
# 21348     21349              L
# 21349     21350              S
#
# [21350 rows x 2 columns]

# %%
# result['pizza_full_name'] = result['pizza_full_name'].apply(lambda x: str(x))

# %%
sampled_data = result.sample(n=20, random_state=42)
print(sampled_data)
# Out:
#        order_id     pizza_size
# 19269     19270              L
# 4634       4635           S; S
# 5412       5413              S
# 812         813           S; L
# 19801     19802              L
# 12542     12543           M; M
# 6491       6492              M
# 1215       1216              M
# 18559     18560              M
# 2812       2813   S; L; L; XXL
# 5800       5801              M
# 12393     12394        M; L; L
# 13101     13102              L
# 13177     13178        L; S; S
# 19271     19272     S; M; M; L
# 21244     21245              L
# 640         641     M; L; M; S
# 6206       6207  S; M; S; L; M
# 4160       4161        M; L; M
# 13777     13778              S

# %%
sampled_data.to_excel('samplingPizzaSIZE.xlsx', index=False)  # index=False untuk tidak menyimpan indeks

# %%
transactions = sampled_data['pizza_full_name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pizza_full_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 transactions = sampled_data['pizza_full_name']
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'pizza_full_name'

# %%
transactions
# Out:
# 19269                          The Chicken Pesto Pizza (L)
# 4634     The Big Meat Pizza (S); The Classic Deluxe Piz...
# 5412                              The Napolitana Pizza (S)
# 812      The California Chicken Pizza (S); The Southwes...
# 19801                            The Four Cheese Pizza (L)
# 12542    The Classic Deluxe Pizza (M); The Southwest Ch...
# 6491                        The Barbecue Chicken Pizza (M)
# 1215                        The Barbecue Chicken Pizza (M)
# 18559                      The Italian Capocollo Pizza (M)
# 2812     The Italian Supreme Pizza (S); The Mediterrane...
# 5800                          The Classic Deluxe Pizza (M)
# 12393    The Chicken Alfredo Pizza (M); The Hawaiian Pi...
# 13101                          The Pepper Salami Pizza (L)
# 13177    The Classic Deluxe Pizza (L); The Italian Supr...
# 19271    The Classic Deluxe Pizza (S); The Hawaiian Piz...
# 21244                            The Four Cheese Pizza (L)
# 640      The Pepperoni Pizza (M); The Southwest Chicken...
# 6206     The Big Meat Pizza (S); The Classic Deluxe Piz...
# 4160     The California Chicken Pizza (M); The Five Che...
# 13777                            The Soppressata Pizza (S)
# Name: pizza_full_name, dtype: object

# %%
sampled_data['pizza_full_name'].unique()
# Out:
# array(['The Chicken Pesto Pizza (L)',
#        'The Big Meat Pizza (S); The Classic Deluxe Pizza (S)',
#        'The Napolitana Pizza (S)',
#        'The California Chicken Pizza (S); The Southwest Chicken Pizza (L)',
#        'The Four Cheese Pizza (L)',
#        'The Classic Deluxe Pizza (M); The Southwest Chicken Pizza (M)',
#        'The Barbecue Chicken Pizza (M)',
#        'The Italian Capocollo Pizza (M)',
#        'The Italian Supreme Pizza (S); The Mediterranean Pizza (L); The Greek Pizza (L); The Greek Pizza (XXL)',
#        'The Classic Deluxe Pizza (M)',
#        'The Chicken Alfredo Pizza (M); The Hawaiian Pizza (L); The Southwest Chicken Pizza (L)',
#        'The Pepper Salami Pizza (L)',
#        'The Classic Deluxe Pizza (L); The Italian Supreme Pizza (S); The Southwest Chicken Pizza (S)',
#        'The Classic Deluxe Pizza (S); The Hawaiian Pizza (M); The Mediterranean Pizza (M); The Napolitana Pizza (L)',
#        'The Pepperoni Pizza (M); The Southwest Chicken Pizza (L); The Spinach Pesto Pizza (M); The Spinach and Feta Pizza (S)',
#        'The Big Meat Pizza (S); The Classic Deluxe Pizza (M); The Green Garden Pizza (S); The Southwest Chicken Pizza (L); The Thai Chicken Pizza (M)',
#        'The California Chicken Pizza (M); The Five Cheese Pizza (L); The Spinach Pesto Pizza (M)',
#        'The Soppressata Pizza (S)'], dtype=object)

# %%
from itertools import combinations

# %%
# Fungsi untuk menghitung support
def calculate_support(itemset, transactions):
    count = 0
    for transaction in transactions:
        if all(item in transaction for item in itemset):
            count += 1
    return count / len(transactions)

# %%
# Fungsi untuk menemukan frequent itemsets
def find_frequent_itemsets(transactions, min_support):
    itemsets = []
    items = {item for transaction in transactions for item in transaction}
    
    # Iterasi level itemsets
    k = 1
    while True:
        if k == 1:
            # Itemsets tunggal
            candidates = [{item} for item in items]
        else:
            # Gabungkan frequent itemsets sebelumnya
            candidates = [
                set(i).union(set(j)) for i in itemsets for j in itemsets
                if len(set(i).union(set(j))) == k
            ]
            # Hapus duplikat
            candidates = list(set(frozenset(c) for c in candidates))
        
        # Hitung support kandidat
        frequent_itemsets = []
        for candidate in candidates:
            support = calculate_support(candidate, transactions)
            if support >= min_support:
                frequent_itemsets.append(candidate)
                print(f"Frequent Itemset: {candidate}, Support: {support:.2f}")
        
        # Hentikan jika tidak ada frequent itemsets
        if not frequent_itemsets:
            break
        
        # Simpan frequent itemsets
        itemsets = frequent_itemsets
        k += 1
    
    return itemsets

# %%
# Fungsi untuk menghasilkan aturan asosiasi
def generate_association_rules(frequent_itemsets, transactions, min_confidence):
    rules = []
    for itemset in frequent_itemsets:
        for i in range(1, len(itemset)):
            for antecedent in combinations(itemset, i):
                antecedent = set(antecedent)
                consequent = itemset - antecedent
                if consequent:
                    # Hitung confidence
                    support_itemset = calculate_support(itemset, transactions)
                    support_antecedent = calculate_support(antecedent, transactions)
                    confidence = support_itemset / support_antecedent
                    if confidence >= min_confidence:
                        rules.append((antecedent, consequent, confidence))
                        print(f"Rule: {antecedent} -> {consequent}, Confidence: {confidence:.2f}")
    return rules

# %%
# # Parameter
# min_support = 0.5
# min_confidence = 0.7

# # Jalankan Apriori
# print("Step 1: Frequent Itemsets")
# frequent_itemsets = find_frequent_itemsets(transactions, min_support)

# print("\nStep 2: Association Rules")
# rules = generate_association_rules(frequent_itemsets, transactions, min_confidence)
